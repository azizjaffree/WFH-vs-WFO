# %%
import pandas as pd
import nltk
import numpy as np

# %%
tweets = pd.read_excel('sample.xlsx')
tweets
# Out:
#             type              source  \
# 0     replied_to  Twitter for iPhone
# 1            NaN           TweetDeck
# 2      retweeted      Grassroots DNC
# 3            NaN     Twitter Web App
# 4            NaN           TweetDeck
# ...          ...                 ...
# 1195         NaN             Twitter
# 1196         NaN     Twitter Web App
# 1197         NaN           TweetDeck
# 1198   retweeted             Twitter
# 1199   retweeted         My1stNewApp
#
#                                                    text
# 0     @vijayshekhar @easydesq will help you look for...
# 1     “The secret of getting ahead is getting starte...
# 2     RT @_mediaspace: Hello hybrid style! Our first...
# 3     Hello hybrid style! Our first day back to the ...
# 4     If your business is #movingoffice, we can make...
# ...                                                 ...
# 1195  Does working from home mean more people will r...
# 1196  Future Focused: The 2021 Cybersecurity Landsca...
# 1197  Multiple times power being snapped today in #A...
# 1198  RT @TechjobApp: 📣 #JobAlert\n\n🧑‍💻 Senior in #...
# 1199  RT @mymoneytips: $250 Daily Formula: https://t...
#
# [1200 rows x 3 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AZIZ\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
import re
words = set(nltk.corpus.stopwords.words('english'))
tweet = []
#words = set(nltk.corpus.words.words())
for i in range(0,len(tweets)):
 string = tweets.iloc[i,2]
 string = re.sub(r"http\S+", "", string) #Removes Hyperlink
 string = re.sub('@[^\s]+','',string) #Removes Usernames
 string = re.sub('#[^\s]+','',string) #Removes Hashtags
 tweet.append(string.strip("[").strip("]"))
new_tweet = pd.DataFrame(list(zip(tweet)), columns = ['text'])
new_tweet
# Out:
#                                                    text
# 0       will help you look for a hybrid work space f...
# 1     “The secret of getting ahead is getting starte...
# 2     RT  Hello hybrid style! Our first day back to ...
# 3     Hello hybrid style! Our first day back to the ...
# 4     If your business is  we can make this a painle...
# ...                                                 ...
# 1195  Does working from home mean more people will r...
# 1196  Future Focused: The 2021 Cybersecurity Landsca...
# 1197  Multiple times power being snapped today in   ...
# 1198  RT  📣 \n\n🧑‍💻 Senior in  and \n🏙️ Madiff\n🪙 $2...
# 1199       RT  $250 Daily Formula: \n  Onlinebusiness
#
# [1200 rows x 1 columns]

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sent = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\AZIZ\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Checking the Polarity
#from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#sent = SentimentIntensityAnalyzer()
sentiment_dict = []
for i in range(0,len(new_tweet)):
 sentiment_dict.append(sent.polarity_scores(new_tweet.iloc[i,0]))
positive = []
neutral = []
negative = []
compound = []
for item in sentiment_dict:
 positive.append(item['pos']*100)
 neutral.append(item['neu']*100)
 negative.append(item['neg']*100)
 compound.append(item['compound']*100)
sentiment_df = pd.DataFrame(list(zip(positive, neutral, negative, compound)), columns = ['Positive', 'Neutral', 'Negative', 'Compound'])
 
new_tweet['Positive'] = sentiment_df['Positive']
new_tweet['Negative'] = sentiment_df['Negative']
new_tweet['Neutral'] = sentiment_df['Neutral']
new_tweet['Compound'] = sentiment_df['Compound']

new_tweet
# Out:
#                                                    text  Positive  Negative  \
# 0       will help you look for a hybrid work space f...      12.2       0.0
# 1     “The secret of getting ahead is getting starte...      12.3       0.0
# 2     RT  Hello hybrid style! Our first day back to ...      23.3       0.0
# 3     Hello hybrid style! Our first day back to the ...      27.9       0.0
# 4     If your business is  we can make this a painle...      23.0      16.9
# ...                                                 ...       ...       ...
# 1195  Does working from home mean more people will r...       0.0       0.0
# 1196  Future Focused: The 2021 Cybersecurity Landsca...      34.2       0.0
# 1197  Multiple times power being snapped today in   ...       0.0       0.0
# 1198  RT  📣 \n\n🧑‍💻 Senior in  and \n🏙️ Madiff\n🪙 $2...       0.0       0.0
# 1199       RT  $250 Daily Formula: \n  Onlinebusiness         0.0       0.0
#
#       Neutral  Compound
# 0        87.8     61.24
# 1        87.7     47.38
# 2        76.7     75.00
# 3        72.1     89.08
# 4        60.1     29.60
# ...       ...       ...
# 1195    100.0      0.00
# 1196     65.8     38.18
# 1197    100.0      0.00
# 1198    100.0      0.00
# 1199    100.0      0.00
#
# [1200 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-0d0b337408b1> in <module>
# ----> 1 tweet.describe()
#
# AttributeError: 'list' object has no attribute 'describe'
